# %% [markdown]
# ## Code to compile data from multiple source regarding pulsating aurora and PFISR and write to dictionary
#
# written by Riley Troyer Fall 2021

# %%
# Start by defining the directories where the data is stored
proj_dir = '/media/sf_semeter-inversion/LAMP_Data_saved/'
# pfisr_dir = proj_dir + 'data/pfisr-data/barker-code/'
pfisr_dir = '/media/sf_semeter-inversion/LAMP_Data/'

# %%
# Libraries
#import rtroyer_useful_functions as rt_func

from datetime import datetime as dt
from datetime import time as dt_time
from datetime import timedelta
import datetime
import h5py
import numpy as np
import os
import pickle
import pytz

# %%
def get_isr_data(pfisr_filename, pfisr_data_dir):
    """Function to get relevant data from PFISR datafile.
    INPUT
    pfisr_filename
        type: str
        about: data file name, should be .h5 file
    pfisr_data_dir
        type: str
        about: directory where isr data is stored
    OUTPUT
    utc_time
        type: array of datetimes
        about: time stamp for the start of each measurement
    unix_time
        type: array of floats
        about: unix timestamp for start of each measurement
    pfisr_altitude
        type: array of float
        about: altitude stamp for each measurement in meters
    e_density
        type: array of float
        about: electron number density in m^-3
    de_density
        type: array of float
        about: error in number density
    """
    
    # Read in the h5 file
    pfisr_file = h5py.File(pfisr_data_dir + pfisr_filename, 'r')

    # Get the different beams and select specified angle
    beam_angle = 90
    beams = np.array(pfisr_file['BeamCodes'])

    # Get the beam with a 90 degree elevation angle
    indexes = np.linspace(0, len(beams)-1, len(beams))
    beam_num = int(indexes[np.abs(beams[:,2] - beam_angle) == 0][0])

    # Get time and convert to utc datetime
    unix_time = np.array(pfisr_file['Time']['UnixTime'])[:,0]
    utc_time = np.array([datetime.datetime.utcfromtimestamp(d) 
                         for d in unix_time])

    # Get the altitude array
    pfisr_altitude = np.array(pfisr_file['NeFromPower']
                              ['Altitude'])[beam_num, :]

    # Get the uncorrected number density array
    e_density = np.array(pfisr_file['NeFromPower']
                         ['Ne_NoTr'])[:, beam_num, :]

    # Take the transpose
    e_density = np.transpose(e_density)
    
    # Find the noise floor by averaging between 55km and 60km
    #...assume this should be zero
    
    # Calculate the power given that power = density/range^2
    pfisr_range = np.array(pfisr_file['NeFromPower']
                           ['Range'])[0, :]

    # Turn 1D array into 2D array for elementwise division
    pfisr_range = np.array([pfisr_range,]*e_density.shape[1])
    pfisr_range = np.transpose(pfisr_range)
    pfisr_power = np.divide(e_density, pfisr_range**2)

    # Get the power bias
    noise_floor = np.nanmean(pfisr_power[(pfisr_altitude > 55000)
                                    & (pfisr_altitude < 60000), :],
                              axis=0)

    # Loop through each column and subtract off noise floor
    for j in range(pfisr_power.shape[1]):
        pfisr_power[:, j] = pfisr_power[:, j] - noise_floor[j]   

    # Calculate new unbiased density
    e_density = np.multiply(pfisr_power, pfisr_range**2)
        
    
    # Get error values
    try:
        de_density = np.array(pfisr_file['NeFromPower']
                              ['errNe_NoTr'])[:, beam_num, :]
        de_density = np.transpose(de_density)
    except:
        de_density = np.array(pfisr_file['NeFromPower']
                              ['dNeFrac'])[:, beam_num, :]
        de_density = np.transpose(de_density)
        de_density = de_density * e_density

    # Close file
    pfisr_file.close()
    
    return utc_time, unix_time, pfisr_altitude, e_density, de_density

# %%
# Loop through each pa date and find time from nearest substorm
pa_pfisr_dict = {}

auroral_type = 'pa'
low_alt_cutoff = 60
cutoff = 12

# Define alaska timezone
alaska_tzinfo = pytz.timezone("US/Alaska")
mlt_midnight = dt_time(10, 54, 0)

# Get the date and start time of measurements
date = '2022-03-05'
#start_time = date + ' ' + '10:00:00'
#end_time = date + ' ' + '20:00:00'

start_time = date + ' ' + '08:00:00'
end_time = date + ' ' + '16:00:00'

# Convert to datetime
start_time = dt.strptime(start_time, '%Y-%m-%d %H:%M:%S')
end_time = dt.strptime(end_time, '%Y-%m-%d %H:%M:%S')
date = start_time.date()

# Read in the PFISR data file
date_str = (str(date.year).zfill(4) 
            + str(date.month).zfill(2)
            + str(date.day).zfill(2))
pfisr_files = os.listdir(pfisr_dir)

# Take only h5 files
pfisr_files = [f for f in pfisr_files if f.endswith('.h5')]

# In case there are multiple files just take first one
pfisr_filename = [f for f in pfisr_files if date_str in f][0]
print(pfisr_filename) 

# (pfisr_time,
#  unix_time,
#  pfisr_alt,
#  e_density,
#  de_density) = rt_func.get_isr_data(pfisr_filename, pfisr_dir)
(pfisr_time,
 unix_time,
 pfisr_alt,
 e_density,
 de_density) = get_isr_data(pfisr_filename, pfisr_dir)
#print(e_density)

# Select data over specified altitude range
low_alt_cutoff = 60000

# Select only between 60km and 140km
altitude_slice = (pfisr_alt 
                  < 140000) & (pfisr_alt 
                               > low_alt_cutoff)
e_density = e_density[altitude_slice, :]
de_density = de_density[altitude_slice, :]
pfisr_alt = pfisr_alt[altitude_slice]

# Filter to only between pulsating aurora times
e_density = e_density[:, (pfisr_time >= start_time)
                      & (pfisr_time <= end_time)]
de_density = de_density[:, (pfisr_time >= start_time)
                        & (pfisr_time <= end_time)]
pfisr_time = pfisr_time[(pfisr_time >= start_time)
                        & (pfisr_time <= end_time)]
print(e_density)
print(pfisr_time)
# Out:
# 20220305.001_bc_nenotr_1min.h5
# [[-3.00907315e+09 -1.26200046e+09  3.40608614e+07 ... -8.06954603e+08
#   -9.60211892e+08  5.47959060e+08]
#  [-2.29227398e+09 -2.02374758e+09 -4.18927849e+08 ...  1.76533808e+08
#   -1.22626080e+09 -1.65608009e+08]
#  [-8.56517488e+08 -7.86200601e+08  1.10087757e+09 ... -1.12984456e+09
#   -1.60069352e+09 -2.31929293e+08]
#  ...
#  [-3.45248787e+08  1.94132345e+09  1.88209512e+10 ...  3.86343767e+10
#    4.16396219e+10  4.69654981e+10]
#  [-3.38201227e+08  1.32457443e+10 -4.26803284e+09 ...  4.64801524e+10
#    3.73881236e+10  5.11298735e+10]
#  [ 2.38677315e+09  9.01145847e+09  1.06573126e+10 ...  3.48509977e+10
#    3.93261584e+10  3.43943561e+10]]
# [datetime.datetime(2022, 3, 5, 8, 0, 59)
#  datetime.datetime(2022, 3, 5, 8, 2, 2)
#  datetime.datetime(2022, 3, 5, 8, 3, 5)
#  datetime.datetime(2022, 3, 5, 8, 4, 9)
#  datetime.datetime(2022, 3, 5, 8, 5, 12)
#  datetime.datetime(2022, 3, 5, 8, 6, 16)
#  datetime.datetime(2022, 3, 5, 8, 7, 19)
#  datetime.datetime(2022, 3, 5, 8, 8, 22)
#  datetime.datetime(2022, 3, 5, 8, 9, 26)
#  datetime.datetime(2022, 3, 5, 8, 10, 29)
#  datetime.datetime(2022, 3, 5, 8, 11, 32)
#  datetime.datetime(2022, 3, 5, 8, 12, 36)
#  datetime.datetime(2022, 3, 5, 8, 13, 39)
#  datetime.datetime(2022, 3, 5, 8, 14, 42)
#  datetime.datetime(2022, 3, 5, 8, 15, 46)
#  datetime.datetime(2022, 3, 5, 8, 16, 49)
#  datetime.datetime(2022, 3, 5, 8, 17, 52)
#  datetime.datetime(2022, 3, 5, 8, 18, 56)
#  datetime.datetime(2022, 3, 5, 8, 19, 59)
#  datetime.datetime(2022, 3, 5, 8, 21, 3)
#  datetime.datetime(2022, 3, 5, 8, 22, 6)
#  datetime.datetime(2022, 3, 5, 8, 23, 9)
#  datetime.datetime(2022, 3, 5, 8, 24, 13)
#  datetime.datetime(2022, 3, 5, 8, 25, 16)
#  datetime.datetime(2022, 3, 5, 8, 26, 19)
#  datetime.datetime(2022, 3, 5, 8, 27, 23)
#  datetime.datetime(2022, 3, 5, 8, 28, 26)
#  datetime.datetime(2022, 3, 5, 8, 29, 29)
#  datetime.datetime(2022, 3, 5, 8, 30, 33)
#  datetime.datetime(2022, 3, 5, 8, 31, 36)
#  datetime.datetime(2022, 3, 5, 8, 32, 40)
#  datetime.datetime(2022, 3, 5, 8, 33, 43)
#  datetime.datetime(2022, 3, 5, 8, 34, 46)
#  datetime.datetime(2022, 3, 5, 8, 35, 50)
#  datetime.datetime(2022, 3, 5, 8, 36, 53)
#  datetime.datetime(2022, 3, 5, 8, 37, 56)
#  datetime.datetime(2022, 3, 5, 8, 48, 32)
#  datetime.datetime(2022, 3, 5, 8, 49, 35)
#  datetime.datetime(2022, 3, 5, 8, 50, 39)
#  datetime.datetime(2022, 3, 5, 8, 51, 42)
#  datetime.datetime(2022, 3, 5, 8, 52, 45)
#  datetime.datetime(2022, 3, 5, 8, 53, 49)
#  datetime.datetime(2022, 3, 5, 8, 54, 52)
#  datetime.datetime(2022, 3, 5, 8, 55, 56)
#  datetime.datetime(2022, 3, 5, 8, 56, 59)
#  datetime.datetime(2022, 3, 5, 8, 58, 2)
#  datetime.datetime(2022, 3, 5, 8, 59, 6)
#  datetime.datetime(2022, 3, 5, 9, 0, 9)
#  datetime.datetime(2022, 3, 5, 9, 1, 12)
#  datetime.datetime(2022, 3, 5, 9, 2, 16)
#  datetime.datetime(2022, 3, 5, 9, 3, 19)
#  datetime.datetime(2022, 3, 5, 9, 4, 22)
#  datetime.datetime(2022, 3, 5, 9, 5, 26)
#  datetime.datetime(2022, 3, 5, 9, 6, 29)
#  datetime.datetime(2022, 3, 5, 9, 7, 33)
#  datetime.datetime(2022, 3, 5, 9, 8, 36)
#  datetime.datetime(2022, 3, 5, 9, 9, 39)
#  datetime.datetime(2022, 3, 5, 9, 10, 43)
#  datetime.datetime(2022, 3, 5, 9, 11, 46)
#  datetime.datetime(2022, 3, 5, 9, 12, 49)
#  datetime.datetime(2022, 3, 5, 9, 13, 53)
#  datetime.datetime(2022, 3, 5, 9, 14, 56)
#  datetime.datetime(2022, 3, 5, 9, 15, 59)
#  datetime.datetime(2022, 3, 5, 9, 17, 3)
#  datetime.datetime(2022, 3, 5, 9, 18, 6)
#  datetime.datetime(2022, 3, 5, 9, 19, 9)
#  datetime.datetime(2022, 3, 5, 9, 20, 13)
#  datetime.datetime(2022, 3, 5, 9, 21, 16)
#  datetime.datetime(2022, 3, 5, 9, 22, 20)
#  datetime.datetime(2022, 3, 5, 9, 23, 23)
#  datetime.datetime(2022, 3, 5, 9, 24, 26)
#  datetime.datetime(2022, 3, 5, 9, 25, 30)
#  datetime.datetime(2022, 3, 5, 9, 26, 33)
#  datetime.datetime(2022, 3, 5, 9, 27, 36)
#  datetime.datetime(2022, 3, 5, 9, 28, 40)
#  datetime.datetime(2022, 3, 5, 9, 29, 43)
#  datetime.datetime(2022, 3, 5, 9, 30, 46)
#  datetime.datetime(2022, 3, 5, 9, 31, 50)
#  datetime.datetime(2022, 3, 5, 9, 32, 53)
#  datetime.datetime(2022, 3, 5, 9, 33, 57)
#  datetime.datetime(2022, 3, 5, 9, 35)
#  datetime.datetime(2022, 3, 5, 9, 36, 3)
#  datetime.datetime(2022, 3, 5, 9, 37, 7)
#  datetime.datetime(2022, 3, 5, 9, 38, 10)
#  datetime.datetime(2022, 3, 5, 9, 39, 13)
#  datetime.datetime(2022, 3, 5, 9, 48, 7)
#  datetime.datetime(2022, 3, 5, 9, 49, 10)
#  datetime.datetime(2022, 3, 5, 9, 50, 14)
#  datetime.datetime(2022, 3, 5, 9, 51, 17)
#  datetime.datetime(2022, 3, 5, 9, 52, 21)
#  datetime.datetime(2022, 3, 5, 9, 53, 24)
#  datetime.datetime(2022, 3, 5, 9, 54, 27)
#  datetime.datetime(2022, 3, 5, 9, 55, 31)
#  datetime.datetime(2022, 3, 5, 9, 56, 34)
#  datetime.datetime(2022, 3, 5, 9, 57, 37)
#  datetime.datetime(2022, 3, 5, 9, 58, 41)
#  datetime.datetime(2022, 3, 5, 9, 59, 44)
#  datetime.datetime(2022, 3, 5, 10, 0, 47)
#  datetime.datetime(2022, 3, 5, 10, 1, 51)
#  datetime.datetime(2022, 3, 5, 10, 2, 54)
#  datetime.datetime(2022, 3, 5, 10, 3, 58)
#  datetime.datetime(2022, 3, 5, 10, 5, 1)
#  datetime.datetime(2022, 3, 5, 10, 6, 4)
#  datetime.datetime(2022, 3, 5, 10, 7, 8)
#  datetime.datetime(2022, 3, 5, 10, 8, 11)
#  datetime.datetime(2022, 3, 5, 10, 9, 14)
#  datetime.datetime(2022, 3, 5, 10, 10, 18)
#  datetime.datetime(2022, 3, 5, 10, 11, 21)
#  datetime.datetime(2022, 3, 5, 10, 12, 24)
#  datetime.datetime(2022, 3, 5, 10, 13, 28)
#  datetime.datetime(2022, 3, 5, 10, 14, 31)
#  datetime.datetime(2022, 3, 5, 10, 15, 34)
#  datetime.datetime(2022, 3, 5, 10, 16, 38)
#  datetime.datetime(2022, 3, 5, 10, 17, 41)
#  datetime.datetime(2022, 3, 5, 10, 18, 45)
#  datetime.datetime(2022, 3, 5, 10, 19, 48)
#  datetime.datetime(2022, 3, 5, 10, 20, 51)
#  datetime.datetime(2022, 3, 5, 10, 21, 55)
#  datetime.datetime(2022, 3, 5, 10, 22, 58)
#  datetime.datetime(2022, 3, 5, 10, 24, 1)
#  datetime.datetime(2022, 3, 5, 10, 25, 5)
#  datetime.datetime(2022, 3, 5, 10, 26, 8)
#  datetime.datetime(2022, 3, 5, 10, 27, 11)
#  datetime.datetime(2022, 3, 5, 10, 28, 15)
#  datetime.datetime(2022, 3, 5, 10, 29, 18)
#  datetime.datetime(2022, 3, 5, 10, 30, 22)
#  datetime.datetime(2022, 3, 5, 10, 31, 25)
#  datetime.datetime(2022, 3, 5, 10, 32, 28)
#  datetime.datetime(2022, 3, 5, 10, 33, 32)
#  datetime.datetime(2022, 3, 5, 10, 34, 35)
#  datetime.datetime(2022, 3, 5, 10, 35, 38)
#  datetime.datetime(2022, 3, 5, 10, 36, 42)
#  datetime.datetime(2022, 3, 5, 10, 37, 45)
#  datetime.datetime(2022, 3, 5, 10, 38, 48)
#  datetime.datetime(2022, 3, 5, 10, 39, 52)
#  datetime.datetime(2022, 3, 5, 10, 40, 55)
#  datetime.datetime(2022, 3, 5, 10, 41, 58)
#  datetime.datetime(2022, 3, 5, 10, 47, 27)
#  datetime.datetime(2022, 3, 5, 10, 48, 31)
#  datetime.datetime(2022, 3, 5, 10, 49, 34)
#  datetime.datetime(2022, 3, 5, 10, 50, 37)
#  datetime.datetime(2022, 3, 5, 10, 51, 41)
#  datetime.datetime(2022, 3, 5, 10, 52, 44)
#  datetime.datetime(2022, 3, 5, 10, 53, 47)
#  datetime.datetime(2022, 3, 5, 10, 54, 51)
#  datetime.datetime(2022, 3, 5, 10, 55, 54)
#  datetime.datetime(2022, 3, 5, 10, 56, 57)
#  datetime.datetime(2022, 3, 5, 10, 58, 1)
#  datetime.datetime(2022, 3, 5, 10, 59, 4)
#  datetime.datetime(2022, 3, 5, 11, 0, 8)
#  datetime.datetime(2022, 3, 5, 11, 1, 11)
#  datetime.datetime(2022, 3, 5, 11, 2, 14)
#  datetime.datetime(2022, 3, 5, 11, 3, 18)
#  datetime.datetime(2022, 3, 5, 11, 4, 21)
#  datetime.datetime(2022, 3, 5, 11, 5, 24)
#  datetime.datetime(2022, 3, 5, 11, 6, 28)
#  datetime.datetime(2022, 3, 5, 11, 7, 31)
#  datetime.datetime(2022, 3, 5, 11, 8, 34)
#  datetime.datetime(2022, 3, 5, 11, 9, 38)
#  datetime.datetime(2022, 3, 5, 11, 10, 41)
#  datetime.datetime(2022, 3, 5, 11, 11, 44)
#  datetime.datetime(2022, 3, 5, 11, 12, 48)
#  datetime.datetime(2022, 3, 5, 11, 13, 51)
#  datetime.datetime(2022, 3, 5, 11, 14, 55)
#  datetime.datetime(2022, 3, 5, 11, 15, 58)
#  datetime.datetime(2022, 3, 5, 11, 17, 1)
#  datetime.datetime(2022, 3, 5, 11, 18, 5)
#  datetime.datetime(2022, 3, 5, 11, 19, 8)
#  datetime.datetime(2022, 3, 5, 11, 20, 11)
#  datetime.datetime(2022, 3, 5, 11, 21, 15)
#  datetime.datetime(2022, 3, 5, 11, 22, 18)
#  datetime.datetime(2022, 3, 5, 11, 23, 21)
#  datetime.datetime(2022, 3, 5, 11, 24, 25)
#  datetime.datetime(2022, 3, 5, 11, 25, 28)
#  datetime.datetime(2022, 3, 5, 11, 26, 32)
#  datetime.datetime(2022, 3, 5, 11, 27, 35)
#  datetime.datetime(2022, 3, 5, 11, 28, 38)
#  datetime.datetime(2022, 3, 5, 11, 29, 42)
#  datetime.datetime(2022, 3, 5, 11, 30, 45)
#  datetime.datetime(2022, 3, 5, 11, 31, 48)
#  datetime.datetime(2022, 3, 5, 11, 32, 52)
#  datetime.datetime(2022, 3, 5, 11, 33, 55)
#  datetime.datetime(2022, 3, 5, 11, 34, 58)
#  datetime.datetime(2022, 3, 5, 11, 36, 2)
#  datetime.datetime(2022, 3, 5, 11, 37, 5)
#  datetime.datetime(2022, 3, 5, 11, 38, 8)
#  datetime.datetime(2022, 3, 5, 11, 39, 12)
#  datetime.datetime(2022, 3, 5, 11, 40, 15)
#  datetime.datetime(2022, 3, 5, 11, 41, 19)
#  datetime.datetime(2022, 3, 5, 11, 42, 22)
#  datetime.datetime(2022, 3, 5, 11, 43, 25)
#  datetime.datetime(2022, 3, 5, 11, 54, 54)
#  datetime.datetime(2022, 3, 5, 11, 55, 57)
#  datetime.datetime(2022, 3, 5, 11, 57, 1)
#  datetime.datetime(2022, 3, 5, 11, 58, 4)
#  datetime.datetime(2022, 3, 5, 11, 59, 8)
#  datetime.datetime(2022, 3, 5, 12, 0, 11)
#  datetime.datetime(2022, 3, 5, 12, 1, 14)
#  datetime.datetime(2022, 3, 5, 12, 2, 18)
#  datetime.datetime(2022, 3, 5, 12, 3, 21)
#  datetime.datetime(2022, 3, 5, 12, 4, 24)
#  datetime.datetime(2022, 3, 5, 12, 5, 28)
#  datetime.datetime(2022, 3, 5, 12, 6, 31)
#  datetime.datetime(2022, 3, 5, 12, 7, 34)
#  datetime.datetime(2022, 3, 5, 12, 8, 38)
#  datetime.datetime(2022, 3, 5, 12, 9, 41)
#  datetime.datetime(2022, 3, 5, 12, 10, 44)
#  datetime.datetime(2022, 3, 5, 12, 11, 48)
#  datetime.datetime(2022, 3, 5, 12, 12, 51)
#  datetime.datetime(2022, 3, 5, 12, 13, 55)
#  datetime.datetime(2022, 3, 5, 12, 14, 58)
#  datetime.datetime(2022, 3, 5, 12, 16, 1)
#  datetime.datetime(2022, 3, 5, 12, 17, 5)
#  datetime.datetime(2022, 3, 5, 12, 18, 8)
#  datetime.datetime(2022, 3, 5, 12, 19, 11)
#  datetime.datetime(2022, 3, 5, 12, 20, 15)
#  datetime.datetime(2022, 3, 5, 12, 21, 18)
#  datetime.datetime(2022, 3, 5, 12, 22, 21)
#  datetime.datetime(2022, 3, 5, 12, 23, 25)
#  datetime.datetime(2022, 3, 5, 12, 24, 28)
#  datetime.datetime(2022, 3, 5, 12, 25, 32)
#  datetime.datetime(2022, 3, 5, 12, 26, 35)
#  datetime.datetime(2022, 3, 5, 12, 27, 38)
#  datetime.datetime(2022, 3, 5, 12, 28, 42)
#  datetime.datetime(2022, 3, 5, 12, 29, 45)
#  datetime.datetime(2022, 3, 5, 12, 30, 48)
#  datetime.datetime(2022, 3, 5, 12, 31, 52)
#  datetime.datetime(2022, 3, 5, 12, 32, 55)
#  datetime.datetime(2022, 3, 5, 12, 33, 58)
#  datetime.datetime(2022, 3, 5, 12, 35, 2)
#  datetime.datetime(2022, 3, 5, 12, 36, 5)
#  datetime.datetime(2022, 3, 5, 12, 37, 8)
#  datetime.datetime(2022, 3, 5, 12, 38, 12)
#  datetime.datetime(2022, 3, 5, 12, 39, 15)
#  datetime.datetime(2022, 3, 5, 12, 40, 19)
#  datetime.datetime(2022, 3, 5, 12, 41, 22)
#  datetime.datetime(2022, 3, 5, 12, 42, 25)
#  datetime.datetime(2022, 3, 5, 12, 43, 29)
#  datetime.datetime(2022, 3, 5, 12, 44, 32)
#  datetime.datetime(2022, 3, 5, 12, 45, 35)
#  datetime.datetime(2022, 3, 5, 12, 46, 39)
#  datetime.datetime(2022, 3, 5, 12, 47, 42)
#  datetime.datetime(2022, 3, 5, 12, 48, 45)
#  datetime.datetime(2022, 3, 5, 12, 49, 49)
#  datetime.datetime(2022, 3, 5, 12, 50, 52)
#  datetime.datetime(2022, 3, 5, 12, 51, 56)
#  datetime.datetime(2022, 3, 5, 12, 52, 59)
#  datetime.datetime(2022, 3, 5, 12, 54, 2)
#  datetime.datetime(2022, 3, 5, 12, 55, 6)
#  datetime.datetime(2022, 3, 5, 12, 56, 9)
#  datetime.datetime(2022, 3, 5, 12, 57, 12)
#  datetime.datetime(2022, 3, 5, 12, 58, 16)
#  datetime.datetime(2022, 3, 5, 12, 59, 19)
#  datetime.datetime(2022, 3, 5, 13, 0, 22)
#  datetime.datetime(2022, 3, 5, 13, 1, 26)
#  datetime.datetime(2022, 3, 5, 13, 2, 29)
#  datetime.datetime(2022, 3, 5, 13, 3, 32)
#  datetime.datetime(2022, 3, 5, 13, 4, 36)
#  datetime.datetime(2022, 3, 5, 13, 5, 39)
#  datetime.datetime(2022, 3, 5, 13, 6, 43)
#  datetime.datetime(2022, 3, 5, 13, 7, 46)
#  datetime.datetime(2022, 3, 5, 13, 8, 49)
#  datetime.datetime(2022, 3, 5, 13, 9, 53)
#  datetime.datetime(2022, 3, 5, 13, 10, 56)
#  datetime.datetime(2022, 3, 5, 13, 11, 59)
#  datetime.datetime(2022, 3, 5, 13, 13, 3)
#  datetime.datetime(2022, 3, 5, 13, 14, 6)
#  datetime.datetime(2022, 3, 5, 13, 15, 9)
#  datetime.datetime(2022, 3, 5, 13, 16, 13)
#  datetime.datetime(2022, 3, 5, 13, 17, 16)
#  datetime.datetime(2022, 3, 5, 13, 18, 19)
#  datetime.datetime(2022, 3, 5, 13, 19, 23)
#  datetime.datetime(2022, 3, 5, 13, 20, 26)
#  datetime.datetime(2022, 3, 5, 13, 21, 30)
#  datetime.datetime(2022, 3, 5, 13, 22, 33)
#  datetime.datetime(2022, 3, 5, 13, 23, 36)
#  datetime.datetime(2022, 3, 5, 13, 24, 40)
#  datetime.datetime(2022, 3, 5, 13, 25, 43)
#  datetime.datetime(2022, 3, 5, 13, 26, 46)
#  datetime.datetime(2022, 3, 5, 13, 27, 50)
#  datetime.datetime(2022, 3, 5, 13, 28, 53)
#  datetime.datetime(2022, 3, 5, 13, 29, 56)
#  datetime.datetime(2022, 3, 5, 13, 31)
#  datetime.datetime(2022, 3, 5, 13, 32, 3)
#  datetime.datetime(2022, 3, 5, 13, 33, 7)
#  datetime.datetime(2022, 3, 5, 13, 34, 10)
#  datetime.datetime(2022, 3, 5, 13, 35, 13)
#  datetime.datetime(2022, 3, 5, 13, 36, 17)
#  datetime.datetime(2022, 3, 5, 13, 37, 20)
#  datetime.datetime(2022, 3, 5, 13, 38, 23)
#  datetime.datetime(2022, 3, 5, 13, 39, 27)
#  datetime.datetime(2022, 3, 5, 13, 40, 30)
#  datetime.datetime(2022, 3, 5, 13, 41, 33)
#  datetime.datetime(2022, 3, 5, 13, 42, 37)
#  datetime.datetime(2022, 3, 5, 13, 43, 40)
#  datetime.datetime(2022, 3, 5, 13, 44, 43)
#  datetime.datetime(2022, 3, 5, 13, 45, 47)
#  datetime.datetime(2022, 3, 5, 13, 46, 50)
#  datetime.datetime(2022, 3, 5, 13, 47, 54)
#  datetime.datetime(2022, 3, 5, 13, 48, 57)
#  datetime.datetime(2022, 3, 5, 13, 50)
#  datetime.datetime(2022, 3, 5, 13, 51, 4)
#  datetime.datetime(2022, 3, 5, 13, 52, 7)
#  datetime.datetime(2022, 3, 5, 13, 53, 10)
#  datetime.datetime(2022, 3, 5, 13, 54, 14)
#  datetime.datetime(2022, 3, 5, 13, 55, 17)
#  datetime.datetime(2022, 3, 5, 13, 56, 20)
#  datetime.datetime(2022, 3, 5, 13, 57, 24)
#  datetime.datetime(2022, 3, 5, 13, 58, 27)
#  datetime.datetime(2022, 3, 5, 13, 59, 31)
#  datetime.datetime(2022, 3, 5, 14, 0, 34)
#  datetime.datetime(2022, 3, 5, 14, 1, 37)
#  datetime.datetime(2022, 3, 5, 14, 2, 41)
#  datetime.datetime(2022, 3, 5, 14, 3, 44)
#  datetime.datetime(2022, 3, 5, 14, 4, 47)
#  datetime.datetime(2022, 3, 5, 14, 5, 51)
#  datetime.datetime(2022, 3, 5, 14, 6, 54)
#  datetime.datetime(2022, 3, 5, 14, 7, 57)
#  datetime.datetime(2022, 3, 5, 14, 9, 1)
#  datetime.datetime(2022, 3, 5, 14, 10, 4)
#  datetime.datetime(2022, 3, 5, 14, 11, 7)
#  datetime.datetime(2022, 3, 5, 14, 12, 11)
#  datetime.datetime(2022, 3, 5, 14, 13, 14)
#  datetime.datetime(2022, 3, 5, 14, 14, 18)
#  datetime.datetime(2022, 3, 5, 14, 15, 21)
#  datetime.datetime(2022, 3, 5, 14, 16, 24)
#  datetime.datetime(2022, 3, 5, 14, 17, 28)
#  datetime.datetime(2022, 3, 5, 14, 18, 31)
#  datetime.datetime(2022, 3, 5, 14, 19, 34)
#  datetime.datetime(2022, 3, 5, 14, 20, 38)
#  datetime.datetime(2022, 3, 5, 14, 21, 41)
#  datetime.datetime(2022, 3, 5, 14, 22, 44)
#  datetime.datetime(2022, 3, 5, 14, 23, 48)
#  datetime.datetime(2022, 3, 5, 14, 24, 51)
#  datetime.datetime(2022, 3, 5, 14, 25, 55)
#  datetime.datetime(2022, 3, 5, 14, 26, 58)
#  datetime.datetime(2022, 3, 5, 14, 28, 1)
#  datetime.datetime(2022, 3, 5, 14, 29, 5)
#  datetime.datetime(2022, 3, 5, 14, 30, 8)
#  datetime.datetime(2022, 3, 5, 14, 31, 11)
#  datetime.datetime(2022, 3, 5, 14, 32, 15)
#  datetime.datetime(2022, 3, 5, 14, 33, 18)
#  datetime.datetime(2022, 3, 5, 14, 34, 21)
#  datetime.datetime(2022, 3, 5, 14, 35, 25)
#  datetime.datetime(2022, 3, 5, 14, 36, 28)
#  datetime.datetime(2022, 3, 5, 14, 37, 31)
#  datetime.datetime(2022, 3, 5, 14, 38, 35)
#  datetime.datetime(2022, 3, 5, 14, 39, 38)
#  datetime.datetime(2022, 3, 5, 14, 40, 42)
#  datetime.datetime(2022, 3, 5, 14, 41, 45)
#  datetime.datetime(2022, 3, 5, 14, 42, 48)
#  datetime.datetime(2022, 3, 5, 14, 43, 52)
#  datetime.datetime(2022, 3, 5, 14, 44, 55)
#  datetime.datetime(2022, 3, 5, 14, 45, 58)
#  datetime.datetime(2022, 3, 5, 14, 47, 2)
#  datetime.datetime(2022, 3, 5, 14, 48, 5)
#  datetime.datetime(2022, 3, 5, 14, 49, 8)
#  datetime.datetime(2022, 3, 5, 14, 50, 12)
#  datetime.datetime(2022, 3, 5, 14, 51, 15)
#  datetime.datetime(2022, 3, 5, 14, 52, 19)
#  datetime.datetime(2022, 3, 5, 14, 53, 22)
#  datetime.datetime(2022, 3, 5, 14, 54, 25)
#  datetime.datetime(2022, 3, 5, 14, 55, 29)
#  datetime.datetime(2022, 3, 5, 14, 56, 32)
#  datetime.datetime(2022, 3, 5, 14, 57, 35)
#  datetime.datetime(2022, 3, 5, 14, 58, 39)
#  datetime.datetime(2022, 3, 5, 14, 59, 42)
#  datetime.datetime(2022, 3, 5, 15, 0, 45)
#  datetime.datetime(2022, 3, 5, 15, 1, 49)
#  datetime.datetime(2022, 3, 5, 15, 2, 52)
#  datetime.datetime(2022, 3, 5, 15, 3, 55)
#  datetime.datetime(2022, 3, 5, 15, 4, 59)
#  datetime.datetime(2022, 3, 5, 15, 6, 2)
#  datetime.datetime(2022, 3, 5, 15, 7, 6)
#  datetime.datetime(2022, 3, 5, 15, 8, 9)
#  datetime.datetime(2022, 3, 5, 15, 9, 12)
#  datetime.datetime(2022, 3, 5, 15, 10, 16)
#  datetime.datetime(2022, 3, 5, 15, 11, 19)
#  datetime.datetime(2022, 3, 5, 15, 12, 22)
#  datetime.datetime(2022, 3, 5, 15, 13, 26)
#  datetime.datetime(2022, 3, 5, 15, 14, 29)
#  datetime.datetime(2022, 3, 5, 15, 15, 32)
#  datetime.datetime(2022, 3, 5, 15, 16, 36)
#  datetime.datetime(2022, 3, 5, 15, 17, 39)
#  datetime.datetime(2022, 3, 5, 15, 18, 43)
#  datetime.datetime(2022, 3, 5, 15, 19, 46)
#  datetime.datetime(2022, 3, 5, 15, 20, 49)
#  datetime.datetime(2022, 3, 5, 15, 21, 53)
#  datetime.datetime(2022, 3, 5, 15, 22, 56)
#  datetime.datetime(2022, 3, 5, 15, 23, 59)
#  datetime.datetime(2022, 3, 5, 15, 25, 3)
#  datetime.datetime(2022, 3, 5, 15, 26, 6)
#  datetime.datetime(2022, 3, 5, 15, 27, 9)
#  datetime.datetime(2022, 3, 5, 15, 28, 13)
#  datetime.datetime(2022, 3, 5, 15, 29, 16)
#  datetime.datetime(2022, 3, 5, 15, 30, 19)
#  datetime.datetime(2022, 3, 5, 15, 31, 23)
#  datetime.datetime(2022, 3, 5, 15, 32, 26)
#  datetime.datetime(2022, 3, 5, 15, 33, 30)
#  datetime.datetime(2022, 3, 5, 15, 34, 33)
#  datetime.datetime(2022, 3, 5, 15, 35, 36)
#  datetime.datetime(2022, 3, 5, 15, 36, 40)
#  datetime.datetime(2022, 3, 5, 15, 37, 43)
#  datetime.datetime(2022, 3, 5, 15, 38, 46)
#  datetime.datetime(2022, 3, 5, 15, 39, 50)
#  datetime.datetime(2022, 3, 5, 15, 40, 53)
#  datetime.datetime(2022, 3, 5, 15, 41, 56)
#  datetime.datetime(2022, 3, 5, 15, 43)
#  datetime.datetime(2022, 3, 5, 15, 44, 3)
#  datetime.datetime(2022, 3, 5, 15, 45, 7)
#  datetime.datetime(2022, 3, 5, 15, 46, 10)
#  datetime.datetime(2022, 3, 5, 15, 47, 13)
#  datetime.datetime(2022, 3, 5, 15, 48, 17)
#  datetime.datetime(2022, 3, 5, 15, 49, 20)
#  datetime.datetime(2022, 3, 5, 15, 50, 23)
#  datetime.datetime(2022, 3, 5, 15, 51, 27)
#  datetime.datetime(2022, 3, 5, 15, 52, 30)
#  datetime.datetime(2022, 3, 5, 15, 53, 33)
#  datetime.datetime(2022, 3, 5, 15, 54, 37)
#  datetime.datetime(2022, 3, 5, 15, 55, 40)
#  datetime.datetime(2022, 3, 5, 15, 56, 43)
#  datetime.datetime(2022, 3, 5, 15, 57, 47)
#  datetime.datetime(2022, 3, 5, 15, 58, 50)
#  datetime.datetime(2022, 3, 5, 15, 59, 54)]

# %%
# Loop through each time and select lowest altitude
for n in range(0, len(pfisr_time)):

    # Select profile for time
    density_profile = e_density[:, n]

    # Also get the profile for the error in this
    error_profile = de_density[:, n]

    # And make sure all of the dates are the same
    profile_time = pfisr_time[n]

    # Get local time and magnetic local time
    ak_time = profile_time.astimezone(alaska_tzinfo)
    ak_time = dt.combine(ak_time.date(), ak_time.time()) 
    mlt_delay = profile_time - dt.combine(profile_time.date(),
                                          mlt_midnight)
    mlt_time = dt.combine(profile_time.date(), 
                          dt_time(0, 0, 0)) + mlt_delay

    # Select only densities > 10^10
    density_slice = density_profile >= 1e10

    # Select only data points with reasonable error
    error_slice = error_profile < 5e9

    # Select only only data points with continuity with previous
    # Select only densities that connect to points above
    continuity_slice = np.zeros(len(pfisr_alt), dtype=bool)

    for j in np.arange(len(pfisr_alt)):

        if j < (len(pfisr_alt) - 20):

            if ((np.min(density_profile[j+1:j+20]) > 0)
                & (np.median(density_profile[j-2:j+2]) 
                   < np.median(density_profile[j+1:j+20]))):
                continuity_slice[j] = True

            else:
                continuity_slice[j] = False

        else: 
            continuity_slice[j] = False

    density_profile = density_profile[density_slice 
                                      & error_slice
                                      & continuity_slice]

    #print(density_profile)
    # Account for possibly no density above threshold
    try:
        # Get lowest altitude value
        lowest_alt = pfisr_alt[density_slice
                               & error_slice
                               & continuity_slice][0]

    except:
        lowest_alt = np.nan

    # Write to dictionary
    pa_pfisr_dict[profile_time] = {'altitude' : lowest_alt,
                                  'local_time' : ak_time,
                                  'mlt_time' : mlt_time}
    print(lowest_alt,ak_time,mlt_time)
print('Finished.')
# Out:
# 111488.703125 2022-03-05 05:00:59 2022-03-04 21:06:59
# 110739.21875 2022-03-05 05:02:02 2022-03-04 21:08:02
# 109240.2578125 2022-03-05 05:03:05 2022-03-04 21:09:05
# 108490.7734375 2022-03-05 05:04:09 2022-03-04 21:10:09
# 109989.734375 2022-03-05 05:05:12 2022-03-04 21:11:12
# 110739.21875 2022-03-05 05:06:16 2022-03-04 21:12:16
# 110739.21875 2022-03-05 05:07:19 2022-03-04 21:13:19
# 109989.734375 2022-03-05 05:08:22 2022-03-04 21:14:22
# 109989.734375 2022-03-05 05:09:26 2022-03-04 21:15:26
# 112238.1796875 2022-03-05 05:10:29 2022-03-04 21:16:29
# 112238.1796875 2022-03-05 05:11:32 2022-03-04 21:17:32
# 108490.7734375 2022-03-05 05:12:36 2022-03-04 21:18:36
# 108490.7734375 2022-03-05 05:13:39 2022-03-04 21:19:39
# 108490.7734375 2022-03-05 05:14:42 2022-03-04 21:20:42
# 108490.7734375 2022-03-05 05:15:46 2022-03-04 21:21:46
# 108490.7734375 2022-03-05 05:16:49 2022-03-04 21:22:49
# 108490.7734375 2022-03-05 05:17:52 2022-03-04 21:23:52
# 106242.3359375 2022-03-05 05:18:56 2022-03-04 21:24:56
# 109240.2578125 2022-03-05 05:19:59 2022-03-04 21:25:59
# 107741.296875 2022-03-05 05:21:03 2022-03-04 21:27:03
# 109989.734375 2022-03-05 05:22:06 2022-03-04 21:28:06
# 108490.7734375 2022-03-05 05:23:09 2022-03-04 21:29:09
# 109240.2578125 2022-03-05 05:24:13 2022-03-04 21:30:13
# 107741.296875 2022-03-05 05:25:16 2022-03-04 21:31:16
# 107741.296875 2022-03-05 05:26:19 2022-03-04 21:32:19
# 107741.296875 2022-03-05 05:27:23 2022-03-04 21:33:23
